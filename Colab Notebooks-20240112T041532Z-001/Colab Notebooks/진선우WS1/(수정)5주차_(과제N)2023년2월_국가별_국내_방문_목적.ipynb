# %% [markdown]
# #화일명을 (5주차 WS)학과_학번_이름.ipynb 로 변경하세요.
# #본인이름폴더(홍길동WS1)를 만드시고 모든 작업은 본인이름 폴더에서 진행해주세요.

# %% [markdown]
# 첨부자료들은 통계청에서 제공하는 **2023년 2월** 국내에 입국한 외국인들의 정보를 **목적별/국적별**로 저장한 자료로써 **교과목 진도에 맞게 재구성한 화일들**입니다.
#
# *공공데이터 URL: https://kosis.kr/statHtml/statHtml.do?orgId=314&tblId=DT_TRD_TGT_ENT_AGG_MONTH&conn_path=I2
#
#
# *   구주 입국목적별 자료.xlsx:  구주 관광/상용/유학연수/기타 자료
# *   국적별 관광 상용 자료.xlxs: 구주를 제외한 관광/상용 자료
# *   국적별 유학연수 기타 자료.csv: 구주를 제외한 유학연수/기타 자료

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #2023년 2월 국내에 입국한 외국인들의 목적별/국적별 자료를 활용하여 다음 질문에 답하기 위한 데이터 분석 과정을 작성하세요.
# ###1)구주에서 상용목적으로 국내에 가장 많이/가장 적게 방문한 국가는 어디인가?
# ###2)아시아주에서 유학연수를 위해 가장 많이/가장 적게 방문한 국가는 어디인가?
# ###3)아시아에서 관광목적으로 국내에 가장 많이/가장 적게 방문한 국가는 어디인가?
# ###4)관광비율이 가장 많은/가장 적은 국가는 어디인가?
# ###5)오대주 중 관광목적으로 가장 많이 방문한 국가는 어디인가?

# %% [markdown]
# ##1.데이터 수집(읽어오기) 및 정보 확인하기

# %%
#정형 데이터를 관리 및 정제하기 위한 라이브러리 읽어오기

import pandas as pd

# %% [markdown]
# ####1)[국적별 관광 상용 자료.xlsx] 화일 읽어오고 행열 정보 및 수치적 통계분포 확인하기

# %%
#[국적별 관광 상용 자료.xlsx] 화일 읽어오기
#상위 5개 데이터 확인하기

관광상용=pd.read_excel('/content/drive/MyDrive/Colab Notebooks/진선우WS1/국적별 관광 상용 자료.xlsx')
관광상용.head()
# Out:
#   국적별(1) 국적별(2)      관광    상용
# 0   아시아주     소계  248483  6209
# 1   아시아주     중국    8813  1340
# 2   아시아주     일본   89217  1084
# 3   아시아주     대만   46456   224
# 4   아시아주     홍콩   15534    49

# %%
#데이터의 구성 확인하기

관광상용.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   국적별(1)  39 non-null     object
#  1   국적별(2)  39 non-null     object
#  2   관광      39 non-null     int64
#  3   상용      39 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 1.3+ KB

# %%
#수치적 통계분포 확인하기

관광상용.describe()
# Out:
#                   관광           상용
# count      39.000000    39.000000
# mean    15108.666667   351.948718
# std     41951.127566  1016.441858
# min        30.000000     1.000000
# 25%       481.500000    23.000000
# 50%      1169.000000    55.000000
# 75%      8783.500000   231.000000
# max    248483.000000  6209.000000

# %% [markdown]
# ####2)[구주 입국목적별 자료.xlsx] 화일 읽어오고 행열 정보 및 *수치형* 데이터 통계분포 확인하기

# %%
#[구주 입국목적별 자료.xlsx] 화일 읽어오기
#상위 10개 데이터 확인하기

구주 =pd.read_excel('/content/drive/MyDrive/Colab Notebooks/진선우WS1/구주 입국목적별 자료.xlsx')
구주.head(10)
# Out:
#   국적별(1) 국적별(2)     관광   상용  유학연수     기타
# 0     구주     소계  24471  520  4981  13249
# 1     구주    러시아   3429   58   500   5088
# 2     구주     영국   3858   67   203    961
# 3     구주     독일   3920  110   850   1302
# 4     구주    프랑스   3785   88  1454   1263
# 5     구주   이탈리아   1414   35   188    241
# 6     구주   네덜란드   1215   11   232   1413
# 7     구주  우크라이나    273   22    52    394
# 8     구주    스페인    893    9   243    162
# 9     구주   루마니아    282    7    32    161

# %%
#데이터의 구성 확인하기

구주.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   국적별(1)  24 non-null     object
#  1   국적별(2)  24 non-null     object
#  2   관광      24 non-null     int64
#  3   상용      24 non-null     int64
#  4   유학연수    24 non-null     int64
#  5   기타      24 non-null     int64
# dtypes: int64(4), object(2)
# memory usage: 1.2+ KB

# %%
#수치형 데이터 통계분포 확인하기

구주.describe(include="all")
# Out:
#        국적별(1) 국적별(2)            관광          상용         유학연수            기타
# count      24     24     24.000000   24.000000    24.000000     24.000000
# unique      1     24           NaN         NaN          NaN           NaN
# top        구주     소계           NaN         NaN          NaN           NaN
# freq       24      1           NaN         NaN          NaN           NaN
# mean      NaN    NaN   2039.250000   43.333333   415.083333   1104.083333
# std       NaN    NaN   4945.183658  105.742783  1024.889768   2792.718185
# min       NaN    NaN     80.000000    0.000000     7.000000     38.000000
# 25%       NaN    NaN    282.750000    5.500000    48.500000     87.000000
# 50%       NaN    NaN    487.500000    8.500000   107.000000    163.000000
# 75%       NaN    NaN   1264.750000   36.250000   234.750000    678.250000
# max       NaN    NaN  24471.000000  520.000000  4981.000000  13249.000000

# %% [markdown]
# ####3)[국적별 유학연수 기타 자료.csv] 화일 읽어오고 행열 정보 및 범주형 데이터 통계분포 확인하기

# %%
#[국적별 유학연수 기타 자료.csv] 화일 읽어오기
#천단위 구분자 삭제하기, encoding 설정하기
#상위 5개 데이터 행 확인하기

유학연수기타 =pd.read_csv('/content/drive/MyDrive/Colab Notebooks/진선우WS1/국적별 유학연수 기타 자료.csv', encoding='EUC_KR')
유학연수기타.head()
# Out:
#   국적별(1) 국적별(2)    유학연수      기타
# 0   아시아주     소계  45,204  60,905
# 1   아시아주     중국  22,250  13,454
# 2   아시아주     일본   2,702   1,318
# 3   아시아주     대만     910     372
# 4   아시아주     홍콩     422     231

# %%
#데이터의 구성 확인하기

유학연수기타.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   국적별(1)  39 non-null     object
#  1   국적별(2)  39 non-null     object
#  2   유학연수    39 non-null     object
#  3   기타      39 non-null     object
# dtypes: object(4)
# memory usage: 1.3+ KB

# %%
#범주형 데이터 통계 분포 확인하기

유학연수기타.describe(include="object")
# Out:
#        국적별(1) 국적별(2) 유학연수      기타
# count      39     39   39      39
# unique      4     36   38      39
# top      아시아주     소계   14  60,905
# freq       26      4    2       1

# %% [markdown]
# ##2.데이터 전처리 및 재설정하기

# %% [markdown]
# ####1)[국적별 관광 상용 자료] 전처리하기

# %%
#열 이름 변경하고 테이블에 적용
#국적별(1) -> 오대주
#국적별(2) -> 국가명
#상위5개 데이터 확인

관광상용.rename(columns={'국적별(1)':'오대주'},inplace=True)
관광상용.rename(columns={'국적별(2)':'국가명'},inplace=True)
관광상용.head()
# Out:
#     오대주 국가명      관광    상용
# 0  아시아주  소계  248483  6209
# 1  아시아주  중국    8813  1340
# 2  아시아주  일본   89217  1084
# 3  아시아주  대만   46456   224
# 4  아시아주  홍콩   15534    49

# %%
#국가명이 [소계]인 행 모두 찾기

관광상용.query('국가명=="소계"')
# Out:
#      오대주 국가명      관광    상용
# 0   아시아주  소계  248483  6209
# 26    미주  소계   37789   233
# 32   대양주  소계    7665   120
# 36  아프리카  소계     682   301

# %%
#국가명이 [소계]인 행 삭제하고 테이블에 적용
#상위5개확인

관광상용.drop(index=[0,26,32,36], axis=1,  inplace= True)
관광상용.head()
# Out:
#     오대주  국가명     관광    상용
# 1  아시아주   중국   8813  1340
# 2  아시아주   일본  89217  1084
# 3  아시아주   대만  46456   224
# 4  아시아주   홍콩  15534    49
# 5  아시아주  마카오    312     3

# %% [markdown]
# ####2)[구주 입국목적별 자료] 전처리하기

# %%
#열 이름 변경하고 테이블에 적용
#국적별(1) -> 오대주
#국적별(2) -> 국가명
#상위5개 데이터 확인

구주.rename(columns={'국적별(1)':'오대주'},inplace=True)
구주.rename(columns={'국적별(2)':'국가명'},inplace=True)
구주.head()
# Out:
#   오대주  국가명     관광   상용  유학연수     기타
# 0  구주   소계  24471  520  4981  13249
# 1  구주  러시아   3429   58   500   5088
# 2  구주   영국   3858   67   203    961
# 3  구주   독일   3920  110   850   1302
# 4  구주  프랑스   3785   88  1454   1263

# %%
#국가명이 [소계]인 행 모두 찾기

구주.query('국가명=="소계"')
# Out:
#   오대주 국가명     관광   상용  유학연수     기타
# 0  구주  소계  24471  520  4981  13249

# %%
#국가명이 [소계]인 행 삭제하고 테이블에 적용
#상위5개확인

구주.drop(index=[0], axis=1,  inplace= True)
구주.head()
# Out:
#   오대주   국가명    관광   상용  유학연수    기타
# 1  구주   러시아  3429   58   500  5088
# 2  구주    영국  3858   67   203   961
# 3  구주    독일  3920  110   850  1302
# 4  구주   프랑스  3785   88  1454  1263
# 5  구주  이탈리아  1414   35   188   241

# %% [markdown]
# ####3)[국적별 유학연수 기타 자료] 전처리하기

# %%
#열 이름 변경하고 테이블에 적용
#국적별(1) -> 오대주
#국적별(2) -> 국가명
#상위5개 데이터 확인

유학연수기타.rename(columns={'국적별(1)':'오대주'},inplace=True)
유학연수기타.rename(columns={'국적별(2)':'국가명'},inplace=True)
유학연수기타.head()
# Out:
#     오대주 국가명    유학연수      기타
# 0  아시아주  소계  45,204  60,905
# 1  아시아주  중국  22,250  13,454
# 2  아시아주  일본   2,702   1,318
# 3  아시아주  대만     910     372
# 4  아시아주  홍콩     422     231

# %%
#국가명이 [소계]인 행 모두 찾기

유학연수기타.query('국가명=="소계"')
# Out:
#      오대주 국가명    유학연수      기타
# 0   아시아주  소계  45,204  60,905
# 26    미주  소계   2,315  16,478
# 32   대양주  소계     112   1,689
# 36  아프리카  소계     495   1,709

# %%
#국가명이 [소계]인 행 삭제하고 테이블에 적용
#상위5개확인

유학연수기타.drop(index=[0,26,32,36], axis=1, inplace= True)
유학연수기타.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-cee7c81bae50> in <cell line: 4>()
#       2 #상위5개확인
#       3
# ----> 4 유학연수기타.drop(index=[0,26,32,36], axis=1, inplace= True)
#       5 유학연수기타.head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# ...

# %% [markdown]
# ##3.3개의 테이블 결합하기

# %% [markdown]
# ####1)[국적별 관광 상용 자료]와 [국적별 유학연수 기타 자료] 열방향으로 결합하기

# %%
#열방향으로 결합하기

merge1 = pd.merge(관광상용,유학연수기타 , on='오대주')
merge1
# Out:
#       오대주     국가명_x    관광    상용     국가명_y    유학연수      기타
# 0    아시아주        중국  8813  1340        중국  22,250  13,454
# 1    아시아주        중국  8813  1340        일본   2,702   1,318
# 2    아시아주        중국  8813  1340        대만     910     372
# 3    아시아주        중국  8813  1340        홍콩     422     231
# 4    아시아주        중국  8813  1340       마카오      24       7
# ..    ...       ...   ...   ...       ...     ...     ...
# 658   대양주    대양주 기타    39     1    대양주 기타       3       9
# 659  아프리카  남아프리카공화국   210     3  남아프리카공화국      14     703
# 660  아프리카  남아프리카공화국   210     3   아프리카 기타     481   1,006
# 661  아프리카   아프리카 기타   472   298  남아프리카공화국      14     703
# 662  아프리카   아프리카 기타   472   298   아프리카 기타     481   1,006
#
# [663 rows x 7 columns]

# %% [markdown]
# ####2)상위 테이블(merge1)과 [구주 입국목적별 자료] 행방향으로 결합하기

# %%
#행방향으로 결합하기

mergeData =pd.concat([merge1, 구주])
mergeData
# Out:
#      오대주 국가명_x    관광    상용 국가명_y    유학연수      기타    국가명
# 0   아시아주    중국  8813  1340    중국  22,250  13,454    NaN
# 1   아시아주    중국  8813  1340    일본   2,702   1,318    NaN
# 2   아시아주    중국  8813  1340    대만     910     372    NaN
# 3   아시아주    중국  8813  1340    홍콩     422     231    NaN
# 4   아시아주    중국  8813  1340   마카오      24       7    NaN
# ..   ...   ...   ...   ...   ...     ...     ...    ...
# 19    구주   NaN   283     3   NaN      16     142    그리스
# 20    구주   NaN    80     0   NaN      30      38   불가리아
# 21    구주   NaN   347     8   NaN      59      66    덴마크
# 22    구주   NaN   295     7   NaN      20     101   아일랜드
# 23    구주   NaN   887    40   NaN     345     584  구주 기타
#
# [686 rows x 8 columns]

# %%
#index 재설정하기(reset_index사용)


mergeData.reset_index(drop=True, inplace=True)

# %% [markdown]
# ##4.데이터 분석하기(질문에 답하기)

# %% [markdown]
# ####1)구주에서 상용목적으로 국내에 가장 많이/가장 적게 방문한 국가는 어디인가?

# %%
# 오대주 중 구주 데이터만 검색하여 저장하기

구주상용목적=mergedata.query('오대주=="구주"')
구주상용목적
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-ee4abe1655f9> in <cell line: 3>()
#       1 # 오대주 중 구주 데이터만 검색하여 저장하기
#       2
# ----> 3 구주상용목적=mergedata.query('오대주=="구주"')
#       4 구주상용목적
#
# NameError: name 'mergedata' is not defined

# %%
# 구주에서 상용 목적에 따라 내림차순 정렬하여 값이 큰 5개 데이터 확인하기

구주.head()
# Out:
#   오대주   국가명    관광   상용  유학연수    기타
# 1  구주   러시아  3429   58   500  5088
# 2  구주    영국  3858   67   203   961
# 3  구주    독일  3920  110   850  1302
# 4  구주   프랑스  3785   88  1454  1263
# 5  구주  이탈리아  1414   35   188   241

# %%
# 구주에서 상용 목적에 따라 오름차순 정렬하여 값이 작은 5개 확인하기

구주.tail()
# Out:
#    오대주    국가명   관광  상용  유학연수   기타
# 19  구주    그리스  283   3    16  142
# 20  구주   불가리아   80   0    30   38
# 21  구주    덴마크  347   8    59   66
# 22  구주   아일랜드  295   7    20  101
# 23  구주  구주 기타  887  40   345  584

# %% [markdown]
# ###2)아시아주에서 유학연수를 위해 가장 많이/가장 적게 방문한 국가는 어디인가?

# %%
#오대주 중 아시아주 검색하여 저장하기

구주.query(['오대주'=="아시아주"])
구주
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-c4fa4b604006> in <cell line: 3>()
#       1 #오대주 중 아시아주 검색하여 저장하기
#       2
# ----> 3 구주.query(['오대주'=="아시아주"])
#       4 구주
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in query(self, expr, inplace, **kwargs)
#    4469         if not isinstance(expr, str):
#    4470             msg = f"expr must be a string to be evaluated, {type(expr)} given"
# -> 4471             raise ValueError(msg)
#    4472         kwargs["level"] = kwargs.pop("level", 0) + 2
# ...

# %%
#아시아주에서 유학연수 목적에 따라 내림정렬하여 상위 5개 확인하기
# Out:
#      오대주     국가명     관광    상용   유학연수     기타
# 0   아시아주      중국   8813  1340  22250  13454
# 8   아시아주     베트남   6377   456  11159  10775
# 1   아시아주      일본  89217  1084   2702   1318
# 13  아시아주  우즈베키스탄    491   166   1491   2496
# 12  아시아주      몽골   8365    41    975    455

# %% [markdown]
# ###3)아시아에서 관광목적으로 국내에 가장 많이/가장 적게 방문한 국가는 어디인가?

# %%
#아시아주에서 관광 목적에 따라 오름 차순 정렬하여 값이 작은 5개 데이터 확인하기
# Out:
#      오대주    국가명   관광  상용  유학연수    기타
# 23  아시아주     이란   30  33    38    30
# 20  아시아주  방글라데시   89  51   297   983
# 19  아시아주   스리랑카  104  22    76  1429
# 21  아시아주   파키스탄  126  91   281   503
# 4   아시아주    마카오  312   3    24     7

# %% [markdown]
# ###4)관광비율이 가장 많은/가장 적은 국가는 어디인가?

# %%
#관광, 상용, 유학연수, 기타의 합계를 가진 '합계'열 생성하기

mergeData['합계'] = mergeData['관광']+mergeData['상용']+mergeData['유학연수']+mergeData['기타']
mergeData.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     164     try:
# --> 165         result = func(left, right)
#     166     except TypeError:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/computation/expressions.py in evaluate(op, a, b, use_numexpr)
#     240             # error: "None" not callable
# --> 241             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     242     return _evaluate_standard(op, op_str, a, b)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     128     if result is None:
# --> 129         result = _evaluate_standard(op, op_str, a, b)
#     130
#
# ...

# %%
#'관광비율(%)' 열 생성하기
#관광비율(%) = 관광 / 합계 * 100

mergeData.head()
# Out:
#     오대주 국가명_x    관광    상용 국가명_y    유학연수      기타  국가명
# 0  아시아주    중국  8813  1340    중국  22,250  13,454  NaN
# 1  아시아주    중국  8813  1340    일본   2,702   1,318  NaN
# 2  아시아주    중국  8813  1340    대만     910     372  NaN
# 3  아시아주    중국  8813  1340    홍콩     422     231  NaN
# 4  아시아주    중국  8813  1340   마카오      24       7  NaN

# %%
#관광 비율이 가장 높은 7개 국가의 데이터 확인하기
# Out:
#      오대주    국가명     관광    상용  유학연수    기타     합계    관광비율(%)
# 2   아시아주     대만  46456   224   910   372  47962  96.860014
# 3   아시아주     홍콩  15534    49   422   231  16236  95.676275
# 1   아시아주     일본  89217  1084  2702  1318  94321  94.588692
# 4   아시아주    마카오    312     3    24     7    346  90.173410
# 10  아시아주  말레이시아  14448    55   464  1510  16477  87.685865
# 7   아시아주     태국  24152    61   361  3377  27951  86.408357
# 22  아시아주   이스라엘    343     5    14    35    397  86.397985

# %%
#관광 비율이 가장 낮은 3개 국가의 데이터 확인하기
# Out:
#      오대주     국가명   관광   상용  유학연수    기타    합계    관광비율(%)
# 20  아시아주   방글라데시   89   51   297   983  1420   6.267606
# 19  아시아주    스리랑카  104   22    76  1429  1631   6.376456
# 13  아시아주  우즈베키스탄  491  166  1491  2496  4644  10.572782

# %% [markdown]
# ###5)오대주 중 관광목적으로 가장 많이 방문한 국가는 어디인가?

# %%
# 오대주 별로 관광 목적에 따른 합계 구하기

오대주관광 =
오대주관광
# Out:
#           관광
# 오대주
# 구주     24471
# 대양주     7665
# 미주     37789
# 아시아주  248483
# 아프리카     682

# %%
ㄴ#오대주관광에서 관광 열의 값이 많은 순서대로 확인
# Out:
#           관광
# 오대주
# 아시아주  248483
# 미주     37789
# 구주     24471
# 대양주     7665
# 아프리카     682
